# %%
preco = 10.5
print(int(preco))
print(type(preco))
# Out:
# 10
# <class 'float'>

# %%
nome = input("Insira seu nome: ")
idade = int(input("Insira sua idade: "))
print(f" Olá {nome}, você tem {idade} anos, e é {"Maior de idade" if (idade >= 18) else "Menor de idade"}" )
# Out:
# Insira seu nome: luis
# Insira sua idade: 16
#  Olá luis, você tem 16 anos, e é Menor de idade
