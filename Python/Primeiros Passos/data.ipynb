# %%
import pandas as pd

# %%
print("Ola, Mundo !")

nome = input("Qual seu nome?: ")
# Convertemos para int() para conseguir fazer contas/comparações
idade = int(input("Qual sua idade?: ")) 

# Se a idade for 18 ou mais, diz "maior de idade", se não, "menor de idade"
print(f"Ola,{nome}. voce tem {idade}, e eh {'maior de idade' if idade >=18 else 'menor'}")
# Out:
# Ola, Mundo !
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_768/241569515.py in <cell line: 0>()
#       3 nome = input("Qual seu nome?: ")
#       4 # Convertemos para int() para conseguir fazer contas/comparações
# ----> 5 idade = int(input("Qual sua idade?: "))
#       6
#       7 # Se a idade for 18 ou mais, diz "maior de idade", se não, "menor de idade"
#
# ValueError: invalid literal for int() with base 10: ' '
