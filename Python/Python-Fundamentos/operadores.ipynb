# %% [markdown]
# <a href="https://colab.research.google.com/github/luisfilipe10/Criando-SAAS-com-IA/blob/main/operadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📌 **Operadores em Python — Guia Rápido**
#
# ### 1. ➕ Operadores Aritméticos
# Usados para realizar cálculos matemáticos:
#
# -   `+` → soma
# -   `-` → subtração
# -   `*` → multiplicação
# -   `/` → divisão
# -   `//` → divisão inteira
# -   `%` → resto da divisão (módulo)
# -   `**` → exponenciação
#
# **✅ Exemplo:**
# ```python
# a = 10
# b = 3
# print(a + b)  # Saída: 13
# print(a % b)  # Saída: 1
# ```
#
# ### 2. ⚖️ Operadores Relacionais (Comparação)
# Comparam valores e retornam `True` ou `False`:
#
# -   `==` → igual
# -   `!=` → diferente
# -   `>` → maior
# -   `<` → menor
# -   `>=` → maior ou igual
# -   `<=` → menor ou igual
#
# **✅ Exemplo:**
# ```python
# x = 5
# print(x == 5)  # Saída: True
# print(x < 3)   # Saída: False
# ```
#
# ### 3. 🔗 Operadores Lógicos
# Usados para combinar expressões booleanas:
#
# -   `and` → verdadeiro se ambos forem verdadeiros
# -   `or` → verdadeiro se ao menos um for verdadeiro
# -   `not` → inverte o resultado
#
# **✅ Exemplo:**
# ```python
# idade = 18
# print(idade >= 18 and idade < 60)  # Saída: True
# ```
#
# ### 4. 🧮 Operadores de Atribuição
# Atribuem valores a variáveis:
#
# -   `=` → atribuição simples
# -   `+=` → soma e atribui
# -   `-=` → subtrai e atribui
# -   `*=` → multiplica e atribui
# -   `/=` → divide e atribui
#
# **✅ Exemplo:**
# ```python
# x = 10
# x += 5  # Equivalente a: x = x + 5
# print(x)  # Saída: 15
# ```
#
# ### 5. 📦 Operadores de Associação (Membership)
# Verificam se um valor está presente em uma sequência (lista, tupla, string, etc.):
#
# -   `in` → pertence
# -   `not in` → não pertence
#
# **✅ Exemplo:**
# ```python
# lista = [1, 2, 3]
# print(2 in lista)      # Saída: True
# print(5 not in lista)  # Saída: True
# ```
#
# ### 6. 🆔 Operadores de Identidade
# Verificam se duas variáveis referenciam o mesmo objeto na memória:
#
# -   `is` → mesma referência
# -   `is not` → referências diferentes
#
# **✅ Exemplo:**
# ```python
# a = [1, 2]
# b = a
# c = [1, 2]
# print(a is b)  # Saída: True (a e b apontam para o mesmo objeto)
# print(a is c)  # Saída: False (a e c são objetos diferentes, mesmo com o mesmo conteúdo)
# ```
#
# ---
#
# 💡 **Resumo:** Os operadores são fundamentais para construir a lógica, realizar cálculos e controlar o fluxo de um programa. Entender bem cada grupo ajuda muito na evolução em Python e na análise de dados.

# %%
nome = input("Insira seu nome: ")
saldo = float(input("Inisira o valor que você tem em na sua conta: "))

sd = print(f"Olá {nome}, o seu saldo do dia é: {saldo}  ")
sq = input(f"{nome}, você pretende fazer algum saque?  (sim / nao): ")

if sq == 'sim':
  saque = float(input("Insira o valor a ser sacado: "))
  print(f"Saque bem sucedido, saldo final: {saldo - saque}" if saque <= saldo else "Saldo insuficiente" )
else:
  print("Obrigado por usar nossos serviços")
# Out:
# Olá Luis, o seu saldo do dia é: 455.0
# Saque bem sucedido, saldo final: 111.0

# %% [markdown]
# Mod para transformação de Tempo

# %%
s = int(input("Insira o tempo em segundos: "))

segundos = s % 60
minutos = s // 60
horas = minutos // 60
minutos_restantes = minutos % 60

# Ajustado para usar: horas, minutos_restantes e segundos
print(f"{s} segundos totaliza: {horas} horas, {minutos_restantes} minutos e {segundos} segundos")
# Out:
# 100 segundos totaliza: 0 horas, 1 minutos e 40 segundos

# %% [markdown]
# Mod para tranformação de medidas

# %%
# 1. Recebe a distância em metros (usando 'm' minúsculo)
m = int(input("Insira a distância em metros (M): "))

# 2. Faz os cálculos corretos
km = m // 1000   # Divisão inteira para saber quantos KM cheios cabem ali
cm = m * 100     # Multiplicação para converter metros em centímetros

# 3. Exibe o resultado formatado
print(f"A distância em KM é: {km} KM, em metros é {m} M, e em centímetros são {cm} cm")
